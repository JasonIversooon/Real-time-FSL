# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %% [markdown]
# # Realtime Test

# %%
from scipy import stats

# %%
colors = [
    (245,117,16), (117,245,16), (16,117,245), (245,117,16), (117,245,16),
    (16,117,245), (245,66,230), (245,66,230), (121,44,250), (121,22,76)
]

def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        color_index = num % len(colors)  # Safeguard against IndexError
        cv2.rectangle(output_frame, (0, 60 + num * 40), (int(prob * 100), 90 + num * 40), colors[color_index], -1)
        cv2.putText(output_frame, actions[num], (0, 85 + num * 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    return output_frame

# %%
# !pip install numpy --upgrade
# Out:
# Requirement already satisfied: numpy in c:\users\iverson\anaconda3\envs\rsl\lib\site-packages (1.21.6)

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow as tf

#'Fast', 'Five', 'Thank You', 'Coffee', 'Cousin', 'One', 'Three', 'Two', 'Wrong', 'Yes'

signs = ['Coffee', 'Cousin','Fast', 'Five', 'One','ThankYou', 'Three','Two','Wrong','Yes']
actions = np.array(['Coffee', 'Cousin','Fast', 'Five', 'One','ThankYou', 'Three','Two','Wrong','Yes'])


mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR-CONVERSION BGR-to-RGB
    image.flags.writeable = False                  # Convert image to not-writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Convert image to writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR-COVERSION RGB-to-BGR
    return image, results


colors = [
    (245,117,16), (117,245,16), (16,117,245), (245,117,16), (117,245,16),
    (16,117,245), (245,66,230), (245,66,230), (121,44,250), (121,22,76)
]

def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        color_index = num % len(colors)  # Safeguard against IndexError
        cv2.rectangle(output_frame, (0, 60 + num * 40), (int(prob * 100), 90 + num * 40), colors[color_index], -1)
        cv2.putText(output_frame, actions[num], (0, 85 + num * 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
    return output_frame


def draw_styled_landmarks(image, results):
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             ) 
    
def extract_keypoints(results):
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([lh, rh])


    
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

model = tf.keras.models.load_model('mrcnn_lstm_model_10C.h5') 



model.load_weights('mrcnn_lstm_weights_10C.h5') 

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.55, min_tracking_confidence=0.55) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-60:]

        if len(sequence)==60:
            res=model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))

            # Vis logic
            if np.unique(predictions[-15:])[0]==np.argmax(res):
                if res[np.argmax(res)] > threshold:
                    if len(sentence) >  0:
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])
                    
            if len(sentence) >  5:
                sentence = sentence[-5:]

            image= prob_viz(res, actions, image,colors)
            
            cv2.rectangle(image, (0,0),(640,40),(245,117,16),-1)
            cv2.putText(image, ' '.join(sentence), (3,30),
                        cv2.FONT_HERSHEY_SIMPLEX,  1, (255,255,255),  2, cv2.LINE_AA)
   
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:From D:\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From D:\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 7s 7s/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 104ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 89ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 94ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 113ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# Fast
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 93ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 78ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 71ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 89ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 82ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 80ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 86ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 98ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 85ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 74ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 99ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 74ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 88ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 71ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 82ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 86ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 79ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 85ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 78ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 89ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 114ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 118ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 132ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 107ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 87ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 74ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 111ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 101ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 89ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 53ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 75ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 79ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 71ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 84ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 77ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 82ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 71ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 82ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 80ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 81ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 80ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 71ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 71ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 71ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 102ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 74ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 80ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 161ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 142ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 92ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 106ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 80ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 101ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 87ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 93ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 71ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 75ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 75ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 84ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 83ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 89ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 82ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 75ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 74ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 107ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 75ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 75ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 78ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 416ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 1s 1s/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 1s 583ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 54ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 81ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 84ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 77ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# Cousin
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 83ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 78ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 83ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 1s 623ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 1s 603ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 415ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 158ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 123ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# One
# ...
# 1/1 [==============================] - 0s 58ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# Two
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 75ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 79ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 77ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 69ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 70ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 77ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 68ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# Five
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 71ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 66ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 65ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 71ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 55ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 74ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 48ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# ThankYou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 61ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 67ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 63ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 74ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 56ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 76ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 64ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 73ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 59ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 62ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 72ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 60ms/step
# One
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 58ms/step
# One

# %%
cap.release()
cv2.destroyAllWindows()

# %%
import tensorflow as tf

# Load the LSTM model
lstm_model = tf.keras.models.load_model('lstm')
# Get LSTM model summary
print("LSTM Model Summary:")
lstm_model.summary()
# Iterate through layers of the LSTM model to get shape and content information
print("\nLSTM Layer-wise Information:")
for layer in lstm_model.layers:
    print("Layer Name:", layer.name)
    print("Layer Type:", layer.__class__.__name__)
    print("Layer Input Shape:", layer.input_shape)
    print("Layer Output Shape:", layer.output_shape)
    print("Layer Weights:")
    for weight in layer.weights:
        print(weight.name, weight.shape)
    print()
# Out:
# WARNING:tensorflow:Layer lstm_78 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_79 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_80 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# LSTM Model Summary:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_78 (LSTM)              (None, 60, 64)            48896
#
#  lstm_79 (LSTM)              (None, 60, 128)           98816
#
#  lstm_80 (LSTM)              (None, 64)                49408
#
#  dense_78 (Dense)            (None, 64)                4160
#
#  dense_79 (Dense)            (None, 32)                2080
#
#  dense_80 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 203,690
# Trainable params: 203,690
# Non-trainable params: 0
# _________________________________________________________________
#
# LSTM Layer-wise Information:
# Layer Name: lstm_78
# Layer Type: LSTM
# Layer Input Shape: (None, 60, 126)
# Layer Output Shape: (None, 60, 64)
# Layer Weights:
# lstm_78/lstm_cell_78/kernel:0 (126, 256)
# lstm_78/lstm_cell_78/recurrent_kernel:0 (64, 256)
# lstm_78/lstm_cell_78/bias:0 (256,)
#
# Layer Name: lstm_79
# Layer Type: LSTM
# Layer Input Shape: (None, 60, 64)
# Layer Output Shape: (None, 60, 128)
# Layer Weights:
# lstm_79/lstm_cell_79/kernel:0 (64, 512)
# lstm_79/lstm_cell_79/recurrent_kernel:0 (128, 512)
# lstm_79/lstm_cell_79/bias:0 (512,)
#
# Layer Name: lstm_80
# Layer Type: LSTM
# Layer Input Shape: (None, 60, 128)
# Layer Output Shape: (None, 64)
# Layer Weights:
# lstm_80/lstm_cell_80/kernel:0 (128, 256)
# lstm_80/lstm_cell_80/recurrent_kernel:0 (64, 256)
# lstm_80/lstm_cell_80/bias:0 (256,)
#
# Layer Name: dense_78
# Layer Type: Dense
# Layer Input Shape: (None, 64)
# Layer Output Shape: (None, 64)
# Layer Weights:
# dense_78/kernel:0 (64, 64)
# dense_78/bias:0 (64,)
#
# Layer Name: dense_79
# Layer Type: Dense
# Layer Input Shape: (None, 64)
# Layer Output Shape: (None, 32)
# Layer Weights:
# dense_79/kernel:0 (64, 32)
# dense_79/bias:0 (32,)
#
# Layer Name: dense_80
# Layer Type: Dense
# Layer Input Shape: (None, 32)
# Layer Output Shape: (None, 10)
# Layer Weights:
# dense_80/kernel:0 (32, 10)
# dense_80/bias:0 (10,)

# %%
# Assuming you have the MRCNN model architecture defined or a model file to load
mrcnn_model = tf.keras.models.load_model('my_npy992')  # Hypothetical model load
# Load weights into the MRCNN model
mrcnn_model.load_weights('npy_weights992.h5')
# Get MRCNN model summary
print("MRCNN Model Summary:")
mrcnn_model.summary()

# Iterate through layers of the MRCNN model to get shape and content information
print("\nMRCNN Layer-wise Information:")
for layer in mrcnn_model.layers:
    print("Layer Name:", layer.name)
    print("Layer Type:", layer.__class__.__name__)
    print("Layer Input Shape:", layer.input_shape)
    print("Layer Output Shape:", layer.output_shape)
    print("Layer Weights:")
    for weight in layer.weights:
        print(weight.name, weight.shape)
    print()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Assuming you have the MRCNN model architecture defined or a model file to load
# ----> 2 mrcnn_model = tf.keras.models.load_model('my_npy992')  # Hypothetical model load
#       3 # Load weights into the MRCNN model
#       4 mrcnn_model.load_weights('npy_weights992.h5')
#
# File ~\anaconda3\envs\lstm\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\envs\lstm\lib\site-packages\keras\saving\save.py:226, in load_model(filepath, custom_objects, compile, options)
#     224 if isinstance(filepath_str, str):
#     225     if not tf.io.gfile.exists(filepath_str):
# --> 226         raise IOError(
#     227             f"No file or directory found at {filepath_str}"
#     228         )
#     230     if tf.io.gfile.isdir(filepath_str):
#     231         return saved_model_load.load(
#     232             filepath_str, compile, options
#     233         )
#
# OSError: No file or directory found at my_npy992
